# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Black_Friday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
# Checking Missing Values in Data.

df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# Unique method will find out how much customer repeats

df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# Converting Male = 1 and Female = 0.

df.Gender.replace('M',1,inplace=True)
df.Gender.replace('F',0,inplace=True)

# %%
df
# Out:
#         User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042       0   0-17          10             A
# 1       1000001  P00248942       0   0-17          10             A
# 2       1000001  P00087842       0   0-17          10             A
# 3       1000001  P00085442       0   0-17          10             A
# 4       1000002  P00285442       1    55+          16             C
# ...         ...        ...     ...    ...         ...           ...
# 550063  1006033  P00372445       1  51-55          13             B
# 550064  1006035  P00375436       0  26-35           1             C
# 550065  1006036  P00375436       0  26-35          15             B
# 550066  1006038  P00375436       0    55+           1             C
# 550067  1006039  P00371644       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.Product_Category_2.value_counts()
# Out:
# Product_Category_2
# 8.0     64088
# 14.0    55108
# 2.0     49217
# 16.0    43255
# 15.0    37855
# 5.0     26235
# 4.0     25677
# 6.0     16466
# 11.0    14134
# 17.0    13320
# 13.0    10531
# 9.0      5693
# 12.0     5528
# 10.0     3043
# 3.0      2884
# 18.0     2770
# 7.0       626
# Name: count, dtype: int64

# %%
df.Product_Category_3.median()
# Out:
# 14.0

# %%
df.Product_Category_3.mode()
# Out:
# 0    16.0
# Name: Product_Category_3, dtype: float64

# %%
df[df.Product_Category_3==8.0]
# Out:
#         User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 29      1000010  P00085942       0  36-45           1             B
# 46      1000010  P00113242       0  36-45           1             B
# 115     1000023  P00177442       1  36-45           0             B
# 184     1000034  P00085942       0  18-25           0             A
# 280     1000048  P00113242       1  26-35           4             B
# ...         ...        ...     ...    ...         ...           ...
# 545590  1005995  P00080342       0  36-45           1             C
# 545748  1006016  P00177442       1  46-50           1             B
# 545803  1006022  P00201442       1  26-35          17             C
# 545882  1006036  P00270542       0  26-35          15             B
# 545898  1006039   P0095042       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 29                             4+               1                   2
# ...

# %%
df.Product_Category_2 = df.Product_Category_2.fillna(8.0)
df.Product_Category_3 = df.Product_Category_3.fillna(16.0)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int64
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# ...

# %%
# Distribution Plot of Purchase

sns.distplot(df.Purchase)
# Out:
# <Axes: xlabel='Purchase', ylabel='Density'>

# %%
# KDE PLot of Purchase Column w.r.t Gender Column.

sns.kdeplot(data=df,x=df.Purchase,hue='Gender')
# Out:
# <Axes: xlabel='Purchase', ylabel='Density'>

# %%
# KDE PLot of Purchase Column w.r.t city column.

sns.kdeplot(data=df,x=df.Purchase,hue='City_Category',fill=True)
# Out:
# <Axes: xlabel='Purchase', ylabel='Density'>

# %%
# KDE PLot of Purchase Column w.r.t Age Group column.

sns.kdeplot(data=df,x=df.Purchase,hue='Age',fill=True)
# Out:
# <Axes: xlabel='Purchase', ylabel='Density'>

# %%
df
# Out:
#         User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042       0   0-17          10             A
# 1       1000001  P00248942       0   0-17          10             A
# 2       1000001  P00087842       0   0-17          10             A
# 3       1000001  P00085442       0   0-17          10             A
# 4       1000002  P00285442       1    55+          16             C
# ...         ...        ...     ...    ...         ...           ...
# 550063  1006033  P00372445       1  51-55          13             B
# 550064  1006035  P00375436       0  26-35           1             C
# 550065  1006036  P00375436       0  26-35          15             B
# 550066  1006038  P00375436       0    55+           1             C
# 550067  1006039  P00371644       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
sns.pairplot(df)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000001B250F52550> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\envs\Skill_Circle\lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~\anaconda3\envs\Skill_Circle\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\envs\Skill_Circle\lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# ...

# %%
# Check for Outiers with Boxplot

sns.boxplot(df.Purchase,orient='h')
# Out:
# KeyboardInterrupt

# %%
px.box(df.Purchase)

# %%
# Finding IQR

Q1,Q3 = df.Purchase.quantile([.25,.75])

# %%
Q1,Q3

# %%
IQR = Q3 - Q1

# %%
IQR

# %%
UL = Q3 + 1.5 * (IQR)
LL = Q1 - 1.5 * (IQR)

# %%
UL

# %%
LL

# %%
df[df.Purchase>UL]

# %%
df.Purchase = np.where(df.Purchase>UL,UL,df.Purchase)

# %%
px.box(df.Purchase)

# %%
px.sscatterplot
